# %%
import numpy as np
import pandas as pd

#shell interface similar to matlab
import matplotlib.pyplot as plt

#data viz lib similar to matlab
import seaborn

#html and xml lib
from bs4 import BeautifulSoup

import sklearn
from sklearn.linear_model import LinearRegression

#http lib 
import requests

# %%
url = "https://www.pro-football-reference.com/years/2007/passing.htm"

# dataframes are 2d tables
dfs = []

re = requests.get(url)
root = BeautifulSoup(re.content)

t = root.find("table")
dfs = pd.read_html(str(t))[0]

dfs
# Out:
#       Rk          Player   Tm Age Pos   G  GS   QBrec  Cmp  Att  ...    Y/G  \
# 0      1     Tom Brady*+  NWE  30  QB  16  16  16-0-0  398  578  ...  300.4
# 1      2      Drew Brees  NOR  28  QB  16  16   7-9-0  440  652  ...  276.4
# 2      3      Tony Romo*  DAL  27  QB  16  16  13-3-0  335  520  ...  263.2
# 3      4    Brett Favre*  GNB  38  QB  16  16  13-3-0  356  535  ...  259.7
# 4      5   Carson Palmer  CIN  28  QB  16  16   7-9-0  373  575  ...  258.2
# ..   ...             ...  ...  ..  ..  ..  ..     ...  ...  ...  ...    ...
# 99    97      Greg Lewis  PHI  27  WR  15   1     NaN    0    1  ...    0.0
# 100   98   Mewelde Moore  MIN  25  RB  12   0     NaN    0    1  ...    0.0
# 101   99  Willie Parker*  PIT  27  RB  15  15     NaN    0    1  ...    0.0
# 102  100      Brad Smith  NYJ  24  WR  16   9     NaN    0    1  ...    0.0
# 103  101  Chester Taylor  MIN  28  RB  14   8     NaN    0    1  ...    0.0
#
#       Rate   QBR  Sk Yds.1  Sk%  NY/A ANY/A  4QC  GWD
# ...

# %%
qbs = []
# remove repeating column headers
dfs[~dfs["Rk"].str.contains("Rk")]

# filter out QBs by QBRec and GS
dfs["QBrec"] = dfs["QBrec"].astype(str) #convert to string
dfs[~dfs["QBrec"].str.contains("NaN")] #remove blank or not a number results
dfs[~dfs["QBrec"].str.contains("nan")]


dfs
# Out:
#       Rk          Player   Tm Age Pos   G  GS   QBrec  Cmp  Att  ...    Y/G  \
# 0      1     Tom Brady*+  NWE  30  QB  16  16  16-0-0  398  578  ...  300.4
# 1      2      Drew Brees  NOR  28  QB  16  16   7-9-0  440  652  ...  276.4
# 2      3      Tony Romo*  DAL  27  QB  16  16  13-3-0  335  520  ...  263.2
# 3      4    Brett Favre*  GNB  38  QB  16  16  13-3-0  356  535  ...  259.7
# 4      5   Carson Palmer  CIN  28  QB  16  16   7-9-0  373  575  ...  258.2
# ..   ...             ...  ...  ..  ..  ..  ..     ...  ...  ...  ...    ...
# 99    97      Greg Lewis  PHI  27  WR  15   1     nan    0    1  ...    0.0
# 100   98   Mewelde Moore  MIN  25  RB  12   0     nan    0    1  ...    0.0
# 101   99  Willie Parker*  PIT  27  RB  15  15     nan    0    1  ...    0.0
# 102  100      Brad Smith  NYJ  24  WR  16   9     nan    0    1  ...    0.0
# 103  101  Chester Taylor  MIN  28  RB  14   8     nan    0    1  ...    0.0
#
#       Rate   QBR  Sk Yds.1  Sk%  NY/A ANY/A  4QC  GWD
# ...
